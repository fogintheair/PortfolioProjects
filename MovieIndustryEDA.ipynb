# %%
import pandas as pd
import seaborn as sns
import numpy as np
import matplotlib.pyplot as plt

# %%
# Load and Understand the Data

# %%
df = pd.read_csv('/Users/furious/Downloads/movies.csv')

df.head()
# Out:
#                                              name rating      genre  year  \
# 0                                     The Shining      R      Drama  1980
# 1                                 The Blue Lagoon      R  Adventure  1980
# 2  Star Wars: Episode V - The Empire Strikes Back     PG     Action  1980
# 3                                       Airplane!     PG     Comedy  1980
# 4                                      Caddyshack      R     Comedy  1980
#
#                         released  score      votes         director  \
# 0  June 13, 1980 (United States)    8.4   927000.0  Stanley Kubrick
# 1   July 2, 1980 (United States)    5.8    65000.0   Randal Kleiser
# 2  June 20, 1980 (United States)    8.7  1200000.0   Irvin Kershner
# 3   July 2, 1980 (United States)    7.7   221000.0     Jim Abrahams
# 4  July 25, 1980 (United States)    7.3   108000.0     Harold Ramis
#
#                     writer            star         country      budget  \
# 0             Stephen King  Jack Nicholson  United Kingdom  19000000.0
# 1  Henry De Vere Stacpoole  Brooke Shields   United States   4500000.0
# 2           Leigh Brackett     Mark Hamill   United States  18000000.0
# 3             Jim Abrahams     Robert Hays   United States   3500000.0
# 4       Brian Doyle-Murray     Chevy Chase   United States   6000000.0
#
#          gross             company  runtime
# 0   46998772.0        Warner Bros.    146.0
# 1   58853106.0   Columbia Pictures    104.0
# 2  538375067.0           Lucasfilm    124.0
# 3   83453539.0  Paramount Pictures     88.0
# 4   39846344.0      Orion Pictures     98.0

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 7668 entries, 0 to 7667
# Data columns (total 15 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   name      7668 non-null   object
#  1   rating    7591 non-null   object
#  2   genre     7668 non-null   object
#  3   year      7668 non-null   int64
#  4   released  7666 non-null   object
#  5   score     7665 non-null   float64
#  6   votes     7665 non-null   float64
#  7   director  7668 non-null   object
#  8   writer    7665 non-null   object
#  9   star      7667 non-null   object
#  10  country   7665 non-null   object
#  11  budget    5497 non-null   float64
#  12  gross     7479 non-null   float64
#  13  company   7651 non-null   object
#  14  runtime   7664 non-null   float64
# dtypes: float64(5), int64(1), object(9)
# memory usage: 898.7+ KB

# %%
df.describe()
# Out:
#               year        score         votes        budget         gross  \
# count  7668.000000  7665.000000  7.665000e+03  5.497000e+03  7.479000e+03
# mean   2000.405451     6.390411  8.810850e+04  3.558988e+07  7.850054e+07
# std      11.153508     0.968842  1.633238e+05  4.145730e+07  1.657251e+08
# min    1980.000000     1.900000  7.000000e+00  3.000000e+03  3.090000e+02
# 25%    1991.000000     5.800000  9.100000e+03  1.000000e+07  4.532056e+06
# 50%    2000.000000     6.500000  3.300000e+04  2.050000e+07  2.020576e+07
# 75%    2010.000000     7.100000  9.300000e+04  4.500000e+07  7.601669e+07
# max    2020.000000     9.300000  2.400000e+06  3.560000e+08  2.847246e+09
#
#            runtime
# count  7664.000000
# mean    107.261613
# std      18.581247
# min      55.000000
# 25%      95.000000
# 50%     104.000000
# 75%     116.000000
# max     366.000000

# %%
# Clean the Data

# %%
for col in df.columns:
    pct_missing = np.mean(df[col].isnull())
    print(f'{col} - {round(pct_missing*100)}%')
# Out:
# name - 0%
# rating - 1%
# genre - 0%
# year - 0%
# released - 0%
# score - 0%
# votes - 0%
# director - 0%
# writer - 0%
# star - 0%
# country - 0%
# budget - 28%
# gross - 2%
# company - 0%
# runtime - 0%

# %%
missing_data = df.isnull().sum()
missing_data
# Out:
# name           0
# rating        77
# genre          0
# year           0
# released       2
# score          3
# votes          3
# director       0
# writer         3
# star           1
# country        3
# budget      2171
# gross        189
# company       17
# runtime        4
# dtype: int64

# %%
df['gross'] = df['gross'].fillna(0)
df['budget'] = df['budget'].fillna(0)

# %%
df['gross'] = df['gross'].astype('int64')
df['budget'] = df['budget'].astype('int64')

# %%
df.dtypes
# Out:
# name         object
# rating       object
# genre        object
# year          int64
# released     object
# score       float64
# votes       float64
# director     object
# writer       object
# star         object
# country      object
# budget        Int64
# gross         Int64
# company      object
# runtime     float64
# dtype: object

# %%
df.isnull().sum()
# Out:
# name         0
# rating      77
# genre        0
# year         0
# released     2
# score        3
# votes        3
# director     0
# writer       3
# star         1
# country      3
# budget       0
# gross        0
# company     17
# runtime      4
# dtype: int64

# %%
df['released'] = df['released'].replace(r'\s\([^)]*\)', '', regex=True)
df.head()
# Out:
#                                              name rating      genre  year  \
# 0                                     The Shining      R      Drama  1980
# 1                                 The Blue Lagoon      R  Adventure  1980
# 2  Star Wars: Episode V - The Empire Strikes Back     PG     Action  1980
# 3                                       Airplane!     PG     Comedy  1980
# 4                                      Caddyshack      R     Comedy  1980
#
#         released  score      votes         director                   writer  \
# 0  June 13, 1980    8.4   927000.0  Stanley Kubrick             Stephen King
# 1   July 2, 1980    5.8    65000.0   Randal Kleiser  Henry De Vere Stacpoole
# 2  June 20, 1980    8.7  1200000.0   Irvin Kershner           Leigh Brackett
# 3   July 2, 1980    7.7   221000.0     Jim Abrahams             Jim Abrahams
# 4  July 25, 1980    7.3   108000.0     Harold Ramis       Brian Doyle-Murray
#
#              star         country    budget      gross             company  \
# 0  Jack Nicholson  United Kingdom  19000000   46998772        Warner Bros.
# 1  Brooke Shields   United States   4500000   58853106   Columbia Pictures
# 2     Mark Hamill   United States  18000000  538375067           Lucasfilm
# 3     Robert Hays   United States   3500000   83453539  Paramount Pictures
# 4     Chevy Chase   United States   6000000   39846344      Orion Pictures
#
#    runtime
# 0    146.0
# 1    104.0
# 2    124.0
# 3     88.0
# 4     98.0

# %%
# convert to datetime format
df['released'] = pd.to_datetime(df['released'], format='%B %d, %Y', errors='coerce')

# check the result
print(df['released'].head())
# Out:
# 0   1980-06-13
# 1   1980-07-02
# 2   1980-06-20
# 3   1980-07-02
# 4   1980-07-25
# Name: released, dtype: datetime64[ns]

# %%
df['released'].dtype
# Out:
# dtype('<M8[ns]')

# %%
df.sort_values(by=['gross'], ascending=False, inplace=False)
# Out:
#                                             name rating    genre  year  \
# 5445                                      Avatar  PG-13   Action  2009
# 7445                           Avengers: Endgame  PG-13   Action  2019
# 3045                                     Titanic  PG-13    Drama  1997
# 6663  Star Wars: Episode VII - The Force Awakens  PG-13   Action  2015
# 7244                      Avengers: Infinity War  PG-13   Action  2018
# ...                                          ...    ...      ...   ...
# 1617                             Mortal Passions      R    Crime  1989
# 1614                              Edge of Sanity      R   Horror  1989
# 1606                                   I, Madman      R  Fantasy  1989
# 1601                        My Twentieth Century    NaN   Comedy  1989
# 7667                                   Tee em el    NaN   Horror  2020
#
#        released  score      votes        director              writer  \
# 5445 2009-12-18    7.8  1100000.0   James Cameron       James Cameron
# 7445 2019-04-26    8.4   903000.0   Anthony Russo  Christopher Markus
# 3045 1997-12-19    7.8  1100000.0   James Cameron       James Cameron
# 6663 2015-12-18    7.8   876000.0     J.J. Abrams     Lawrence Kasdan
# 7244 2018-04-27    8.4   897000.0   Anthony Russo  Christopher Markus
# ...         ...    ...        ...             ...                 ...
# 1617 1990-01-26    4.5      274.0     Andrew Lane      Alan Moskowitz
# 1614 1989-04-14    5.2     1300.0  Gérard Kikoïne          J.P. Félix
# 1606 1989-04-07    6.0     2900.0    Tibor Takács       David Chaskin
# 1601 1990-01-13    7.1     1500.0   Ildikó Enyedi       Ildikó Enyedi
# 7667 2020-08-19    5.7        7.0    Pereko Mosia        Pereko Mosia
#
#                    star         country     budget       gross  \
# 5445    Sam Worthington   United States  237000000  2847246203
# 7445  Robert Downey Jr.   United States  356000000  2797501328
# 3045  Leonardo DiCaprio   United States  200000000  2201647264
# 6663       Daisy Ridley   United States  245000000  2069521700
# 7244  Robert Downey Jr.   United States  321000000  2048359754
# ...                 ...             ...        ...         ...
# 1617      Zach Galligan   United States          0           0
# 1614    Anthony Perkins  United Kingdom          0           0
# 1606       Jenny Wright          Canada          0           0
# 1601       Dorota Segda         Hungary          0           0
# 7667   Siyabonga Mabaso    South Africa          0           0
#
#                               company  runtime
# 5445            Twentieth Century Fox    162.0
# 7445                   Marvel Studios    181.0
# 3045            Twentieth Century Fox    194.0
# 6663                        Lucasfilm    138.0
# 7244                   Marvel Studios    149.0
# ...                               ...      ...
# 1617          Gibraltar Entertainment     92.0
# 1614                    Allied Vision     85.0
# 1606  Trans World Entertainment (TWE)     89.0
# 1601         Budapest Stúdió Vállalat    104.0
# 7667                      PK 65 Films    102.0
#
# [7668 rows x 15 columns]

# %%
df['company'].drop_duplicates().sort_values()
# Out:
# 4345        "DIA" Productions GmbH & Co. KG
# 7525    "Weathering With You" Film Partners
# 3024                        .406 Production
# 3748                     1+2 Seisaku Iinkai
# 5813                        10 West Studios
#                        ...
# 4007                               i5 Films
# 6412               iDeal Partners Film Fund
# 5664                            micro_scope
# 7129                                thefyzz
# 408                                     NaN
# Name: company, Length: 2386, dtype: object

# %%
# detect the outliers

numeric_columns = ['gross', 'budget', 'runtime']

for column in numeric_columns:
    plt.figure(figsize=(6,4))
    sns.boxplot(x=df[column], color='skyblue')
    plt.title(f'Boxplot of {column}')
    plt.xlabel(column)
    plt.show()

# %%
# to list outliers of gross

Q1 = df['gross'].quantile(0.25)
Q3 = df['gross'].quantile(0.75)

# IQR

IQR = Q3 - Q1  
lower_bound = Q1 - 1.5 * IQR
upper_bound = Q3 + 1.5 * IQR

# find outliers

outliers = df[(df['gross'] < lower_bound) | (df['gross'] > upper_bound)]
print(outliers)
# Out:
#                                                 name     rating      genre  \
# 2     Star Wars: Episode V - The Empire Strikes Back         PG     Action
# 92     Indiana Jones and the Raiders of the Lost Ark         PG     Action
# 209                       E.T. the Extra-Terrestrial         PG     Family
# 221                                          Tootsie         PG     Comedy
# 333       Star Wars: Episode VI - Return of the Jedi         PG     Action
# ...                                              ...        ...        ...
# 7648                               Bad Boys for Life          R     Action
# 7649                              Sonic the Hedgehog         PG     Action
# 7650                                        Dolittle         PG  Adventure
# 7652                               The Eight Hundred  Not Rated     Action
# 7655                           Legend of Deification      TV-PG  Animation
#
#       year   released  score      votes          director            writer  \
# 2     1980 1980-06-20    8.7  1200000.0    Irvin Kershner    Leigh Brackett
# 92    1981 1981-06-12    8.4   905000.0  Steven Spielberg   Lawrence Kasdan
# 209   1982 1982-06-11    7.8   381000.0  Steven Spielberg  Melissa Mathison
# 221   1982 1982-12-17    7.4   100000.0    Sydney Pollack       Don McGuire
# 333   1983 1983-05-25    8.3   973000.0  Richard Marquand   Lawrence Kasdan
# ...    ...        ...    ...        ...               ...               ...
# 7648  2020 2020-01-17    6.6   140000.0      Adil El Arbi       Peter Craig
# 7649  2020 2020-02-14    6.5   102000.0       Jeff Fowler         Pat Casey
# 7650  2020 2020-01-17    5.6    53000.0    Stephen Gaghan    Stephen Gaghan
# 7652  2020 2020-08-28    6.8     3700.0           Hu Guan           Hu Guan
# 7655  2020 2020-10-01    6.6     1300.0        Teng Cheng               NaN
#
#                    star        country     budget      gross  \
# 2           Mark Hamill  United States   18000000  538375067
# 92        Harrison Ford  United States   18000000  389925971
# 209        Henry Thomas  United States   10500000  792910554
# 221      Dustin Hoffman  United States   21000000  177200000
# 333         Mark Hamill  United States   32500000  475106177
# ...                 ...            ...        ...        ...
# 7648         Will Smith  United States   90000000  426505244
# 7649       Ben Schwartz  United States   85000000  319715683
# 7650  Robert Downey Jr.  United States  175000000  245487753
# 7652    Zhi-zhong Huang          China   80000000  461421559
# 7655     Guangtao Jiang          China          0  240663149
#
#                                   company  runtime
# 2                               Lucasfilm    124.0
# 92                     Paramount Pictures    115.0
# 209                    Universal Pictures    115.0
# 221                     Columbia Pictures    116.0
# 333                             Lucasfilm    131.0
# ...                                   ...      ...
# 7648                    Columbia Pictures    124.0
# 7649                   Paramount Pictures     99.0
# 7650                   Universal Pictures    101.0
# 7652  Beijing Diqi Yinxiang Entertainment    149.0
# 7655             Beijing Enlight Pictures    110.0
#
# [907 rows x 15 columns]

# %%
# to list outliers of budget

Q1_b = df['budget'].quantile(0.25)
Q3_b = df['budget'].quantile(0.75)
IQR_b = Q3_b - Q1_b

lower_bound_b = Q1_b - 1.5 * IQR_b
upper_bound_b = Q3_b + 1.5 * IQR_b

out_liners_b = df[(df['budget'] < lower_bound_b) | (df['budget'] > upper_bound_b)]
print(out_liners_b)
# Out:
#                             name rating      genre  year   released  score  \
# 1843  Terminator 2: Judgment Day      R     Action  1991 1991-07-03    8.5
# 2262            Last Action Hero  PG-13     Action  1993 1993-06-18    6.4
# 2447                   True Lies      R     Action  1994 1994-07-15    7.2
# 2652              Batman Forever  PG-13     Action  1995 1995-06-16    5.4
# 2656   Die Hard with a Vengeance      R     Action  1995 1995-05-19    7.6
# ...                          ...    ...        ...   ...        ...    ...
# 7645               Birds of Prey      R     Action  2020 2020-02-07    6.1
# 7648           Bad Boys for Life      R     Action  2020 2020-01-17    6.6
# 7649          Sonic the Hedgehog     PG     Action  2020 2020-02-14    6.5
# 7650                    Dolittle     PG  Adventure  2020 2020-01-17    5.6
# 7651        The Call of the Wild     PG  Adventure  2020 2020-02-21    6.8
#
#           votes         director              writer                   star  \
# 1843  1000000.0    James Cameron       James Cameron  Arnold Schwarzenegger
# 2262   141000.0   John McTiernan            Zak Penn  Arnold Schwarzenegger
# 2447   243000.0    James Cameron         Claude Zidi  Arnold Schwarzenegger
# 2652   239000.0  Joel Schumacher            Bob Kane             Val Kilmer
# 2656   370000.0   John McTiernan  Jonathan Hensleigh           Bruce Willis
# ...         ...              ...                 ...                    ...
# 7645   190000.0        Cathy Yan    Christina Hodson          Margot Robbie
# 7648   140000.0     Adil El Arbi         Peter Craig             Will Smith
# 7649   102000.0      Jeff Fowler           Pat Casey           Ben Schwartz
# 7650    53000.0   Stephen Gaghan      Stephen Gaghan      Robert Downey Jr.
# 7651    42000.0    Chris Sanders       Michael Green          Harrison Ford
#
#             country     budget      gross                         company  \
# 1843  United States  102000000  520881154                Carolco Pictures
# 2262  United States   85000000  137298489               Columbia Pictures
# 2447  United States  115000000  378882411           Twentieth Century Fox
# 2652  United States  100000000  336567158                    Warner Bros.
# 2656  United States   90000000  366101666  Cinergi Pictures Entertainment
# ...             ...        ...        ...                             ...
# 7645  United States   84500000  201858461         Clubhouse Pictures (II)
# 7648  United States   90000000  426505244               Columbia Pictures
# 7649  United States   85000000  319715683              Paramount Pictures
# 7650  United States  175000000  245487753              Universal Pictures
# 7651         Canada  135000000  111105497            20th Century Studios
#
#       runtime
# 1843    137.0
# 2262    130.0
# 2447    141.0
# 2652    121.0
# 2656    128.0
# ...       ...
# 7645    109.0
# 7648    124.0
# 7649     99.0
# 7650    101.0
# 7651    100.0
#
# [574 rows x 15 columns]

# %%
# # to list outliers of runtime

Q1_r = df['runtime'].quantile(0.25)
Q3_r = df['runtime'].quantile(0.75)
IQR_r = Q3_r - Q1_r

lower_bound_r = Q1_r - 1.5 * IQR_r
upper_bound_r = Q3_r + 1.5 * IQR_r

out_liners_r = df[(df['runtime'] < lower_bound_r) | (df['runtime'] > upper_bound_r)]
print(out_liners_r)
# Out:
#                                   name     rating      genre  year   released  \
# 21                       Heaven's Gate          R  Adventure  1980 1981-04-24
# 49                  Lion of the Desert         PG  Biography  1980 1981-05-16
# 66    Moscow Does Not Believe in Tears         PG     Comedy  1980 1980-02-11
# 102                           Das Boot        NaN  Adventure  1981 1982-02-10
# 115                               Reds         PG  Biography  1981 1981-12-25
# ...                                ...        ...        ...   ...        ...
# 7613          42nd Street: The Musical  Not Rated    Musical  2019 2019-05-01
# 7634             My People, My Country        NaN      Drama  2019 2019-10-01
# 7643                             Tenet      PG-13     Action  2020 2020-09-03
# 7644                 Wonder Woman 1984      PG-13     Action  2020 2020-12-25
# 7652                 The Eight Hundred  Not Rated     Action  2020 2020-08-28
#
#       score     votes           director             writer  \
# 21      6.8   14000.0     Michael Cimino     Michael Cimino
# 49      8.3   15000.0    Moustapha Akkad       David Butler
# 66      8.1   12000.0   Vladimir Menshov  Valentin Chernykh
# 102     8.3  237000.0  Wolfgang Petersen  Wolfgang Petersen
# 115     7.3   21000.0      Warren Beatty      Warren Beatty
# ...     ...       ...                ...                ...
# 7613    7.9     321.0       Mark Bramble       Mark Bramble
# 7634    6.5    1500.0          Directors            Hu Guan
# 7643    7.4  387000.0  Christopher Nolan  Christopher Nolan
# 7644    5.4  217000.0      Patty Jenkins      Patty Jenkins
# 7652    6.8    3700.0            Hu Guan            Hu Guan
#
#                        star         country     budget      gross  \
# 21       Kris Kristofferson   United States   44000000    3484523
# 49            Anthony Quinn           Libya   35000000          0
# 66            Vera Alentova    Soviet Union     900000          0
# 102         Jürgen Prochnow    West Germany          0   11487676
# 115           Warren Beatty   United States   32000000   40382659
# ...                     ...             ...        ...        ...
# 7613        Bonnie Langford  United Kingdom          0    2217255
# 7634               Bo Huang           China          0  450064993
# 7643  John David Washington   United States  205000000  363656624
# 7644              Gal Gadot   United States          0  166534027
# 7652        Zhi-zhong Huang           China   80000000  461421559
#
#                                      company  runtime
# 21                      Partisan Productions    219.0
# 49          Falcon International Productions    173.0
# 66                                   Mosfilm    150.0
# 102                             Bavaria Film    149.0
# 115   Barclays Mercantile Industrial Finance    195.0
# ...                                      ...      ...
# 7613                   Julian Marsh Pictures    155.0
# 7634                        Alibaba Pictures    154.0
# 7643                            Warner Bros.    150.0
# 7644                     Atlas Entertainment    151.0
# 7652     Beijing Diqi Yinxiang Entertainment    149.0
#
# [240 rows x 15 columns]

# %%
# Exploratory Data Analysis(EDA)

# %%
# Number of movie produced each year

movies_per_year = df.groupby('year')['name'].count()
movies_per_year
# Out:
# year
# 1980     92
# 1981    113
# 1982    126
# 1983    144
# 1984    168
# 1985    200
# 1986    200
# 1987    200
# 1988    200
# 1989    200
# 1990    200
# 1991    200
# 1992    200
# 1993    200
# 1994    200
# 1995    200
# 1996    200
# 1997    200
# 1998    200
# 1999    200
# 2000    200
# 2001    200
# 2002    200
# 2003    200
# 2004    200
# 2005    200
# 2006    200
# 2007    200
# 2008    200
# 2009    200
# 2010    200
# 2011    200
# 2012    200
# 2013    200
# 2014    200
# 2015    200
# 2016    200
# 2017    200
# 2018    200
# 2019    200
# 2020     25
# Name: name, dtype: int64

# %%
plt.figure(figsize=(6,4))

plt.plot(movies_per_year.index, movies_per_year.values, marker='o', color='b', linestyle='-')

plt.title('Number of Movies Produced Over the Years', fontsize=16)
plt.xlabel('Year', fontsize=14)
plt.ylabel('Number of Movies', fontsize=14)
plt.grid(True, alpha=0.6)  

plt.show()

# %%
# Average budget and gross revenue per year

avg_budget_gross = df.groupby('year')[['budget', 'gross']].mean()  
avg_budget_gross.head()
# Out:
#               budget            gross
# year
# 1980  6183152.173913  26996380.043478
# 1981  6278318.584071   22301459.19469
# 1982  6640238.095238  25298258.071429
# 1983     6208163.625  19097254.347222
# 1984  6644797.619048  21030310.690476

# %%
# plot the average budget and gross revenue trends

plt.figure(figsize=(6,4))

plt.plot(avg_budget_gross.index, avg_budget_gross['budget'], label='Avreage Budget', color='g', marker='o')
plt.plot(avg_budget_gross.index, avg_budget_gross['gross'], label='Average Gross Revenue', color='r', marker='o')

plt.title('Average Budget and Gross Revenue Over the Years', fontsize=16)
plt.xlabel('Year', fontsize=14)
plt.ylabel('Amount(in dollars)', fontsize=14)
plt.grid(True, alpha=0.4)  
plt.legend(fontsize=12)    

plt.show()

# %%
# select relevant numeric columns for correlation analysis

correlation_columns = ['budget', 'gross', 'score', 'votes']
correlation_matrix = df[correlation_columns].corr()
correlation_matrix
# Out:
#           budget     gross     score     votes
# budget  1.000000  0.750157  0.055665  0.486862
# gross   0.750157  1.000000  0.186392  0.632834
# score   0.055665  0.186392  1.000000  0.409182
# votes   0.486862  0.632834  0.409182  1.000000

# %%
# Heatmap for correlations

plt.figure(figsize=(6,4))

sns.heatmap(correlation_matrix, annot=True, cmap='coolwarm', fmt='.2f')
plt.title('Correlation Heatmap', fontsize=16)
plt.show()

# %%
# Scatter plot to check relationship between budgrt and gross

plt.figure(figsize=(6,4))

sns.scatterplot(data=df, x='budget', y='gross', alpha=0.4) 
plt.title('Budget vs Gross Revenue', fontsize=16)
plt.xlabel('Budget', fontsize=14)
plt.ylabel('Gross Revenue', fontsize=14)
plt.grid(alpha=0.5)   

plt.show()

# %%
# Scatter plot to check relationship between score and votes

plt.figure(figsize=(6,4))

sns.scatterplot(data=df, x='score', y='votes', alpha=0.6, color='purple')
plt.title('IMDb Score vs Votes', fontsize=16)
plt.xlabel('IMDb Score', fontsize=14)
plt.ylabel('Number of Votes', fontsize=14)
plt.grid(alpha=0.5)

plt.show()

# %%
df['genre'].nunique()
# Out:
# 19

# %%
# Group by genre and calculate average gross and total votes
genre_analysis = df.groupby('genre')[['gross', 'votes']].mean().sort_values(by='gross', ascending=False)
genre_analysis
# Out:
#                       gross          votes
# genre
# Animation  237106644.366864  127672.952663
# Family     196172492.454545   68504.545455
# Action     142777628.008211  140575.814554
# Adventure  107533013.332553  101541.550351
# Mystery         101183527.7  230125.750000
# Biography   46793638.376975   90422.839729
# Horror      45165619.881988   68084.850932
# Comedy      43285286.620045   54283.183964
# Crime       38757619.459165   90930.219601
# Fantasy         37829571.25   58815.909091
# Drama       37648648.575099   69803.542876
# Sci-Fi           26048986.6   88493.000000
# Thriller      20201444.5625   19930.687500
# Romance          18839499.9   35997.400000
# Western     10675295.333333    2066.333333
# Musical           2595346.0     481.000000
# Sport             1067629.0     691.000000
# Music              110014.0   12000.000000
# History                 0.0      79.000000

# %%
# Plot the most popular genres based on gross revenue

plt.figure(figsize=(8,4))

genre_analysis['gross'].sort_values(ascending=False).plot(kind='bar', color='skyblue')

plt.title('Most Popular Genres (Based on Gross Revenue)', fontsize=16)
plt.xlabel('Genre', fontsize=14)
plt.ylabel('Average Gross Revenue', fontsize=14)

plt.show()

# %%
# plot the most popular genres based on votes amount
plt.figure(figsize=(8,4))

genre_analysis = genre_analysis.sort_values('votes', ascending=False)

plt.bar(genre_analysis.index, genre_analysis['votes'], color='pink') 
plt.title('Most popular genres(based on votes)', fontsize=16)
plt.xlabel('Votes', fontsize=14)
plt.ylabel('Average Votes', fontsize=14)
plt.xticks(rotation=90, ha='right')
plt.tight_layout()  

plt.show()

# %%
# Top directors by average gross revenue
top_directors = df.groupby('director')['gross'].mean().sort_values(ascending=False).head(10)
top_directors
# Out:
# director
# Anthony Russo            1368849796.8
# Kyle Balda               1097122396.5
# Josh Cooley              1073394593.0
# Chris Buck          1059908950.666667
# Lee Unkrich               937394349.5
# James Cameron        892584082.571429
# David Yates          860227414.142857
# George Lucas              849751079.0
# J.J. Abrams          776562577.333333
# Robert Stromberg          758411779.0
# Name: gross, dtype: Float64

# %%
# plot top 10 directors
plt.figure(figsize=(6,4))

top_directors.plot(kind='bar', color='skyblue')
plt.title('Top 10 Directors by Average Gross Revenue', fontsize=16)
plt.xlabel('Director', fontsize=14)
plt.ylabel('Average Gross Revenue', fontsize=14)

plt.show()

# %%
# Top stars by avreage gross revenus
top_stars = df.groupby('star')['gross'].mean().sort_values(ascending=False).head(10)
top_stars
# Out:
# star
# Donald Glover           1670727580.0
# Daisy Ridley            1120173808.5
# Neel Sethi               966554929.0
# Craig T. Nelson          938123290.0
# Chris Pratt         879742689.666667
# Louis C.K.               875458631.0
# Anthony Gonzalez         807817888.0
# Yanting Lü               726264074.0
# Tom Holland              718015176.0
# Bill Skarsgård           701796444.0
# Name: gross, dtype: Float64

# %%
# Plot top 10 stars
plt.figure(figsize=(6,5))

top_stars.plot(kind='bar')
plt.title('Top 10 Stars by Average Gross Revenue', fontsize=16)
plt.xlabel('Star', fontsize=14)
plt.ylabel('Average Gross Revenue', fontsize=14)
plt.xticks(rotation=45, ha='right')
plt.tight_layout()

plt.show()

# %%
df['rating'].nunique()
# Out:
# 12

# %%
# Count movies by rating
rating_counts = df['rating'].value_counts()
rating_counts
# Out:
# R            3697
# PG-13        2112
# PG           1252
# Not Rated     283
# G             153
# Unrated        52
# NC-17          23
# TV-MA           9
# TV-PG           5
# X               3
# TV-14           1
# Approved        1
# Name: rating, dtype: int64

# %%
# plot most common ratings

plt.figure(figsize=(6,6))

rating_counts.plot(kind='bar', color='blue')  # 条形图更合适，因为明确表明数量，而非趋势

    
plt.title('Most Common Movie Ratings', fontsize=16)
plt.xlabel('Rating', fontsize=14)
plt.ylabel('Number of movies', fontsize=14)
plt.xticks(rotation=45, ha='right')
plt.tight_layout()

plt.show()

# %%
# Group by year and caculate average budget, gross and runtime
time_analysis = df.groupby('year')[['budget', 'gross', 'runtime']].mean()
time_analysis
# Out:
#               budget            gross     runtime
# year
# 1980  6183152.173913  26996380.043478  107.402174
# 1981  6278318.584071   22301459.19469  105.955752
# 1982  6640238.095238  25298258.071429  105.928571
# 1983     6208163.625  19097254.347222  102.270833
# 1984  6644797.619048  21030310.690476  104.446429
# 1985       6102550.0     18457546.415  102.235000
# 1986      6323936.88      18237559.18  101.805000
# 1987      6912713.39     20167171.275  102.710000
# 1988       8652700.0     24201928.155  103.585000
# 1989      8923812.89     30436253.895  102.710000
# 1990      10362515.0       34021179.3  104.925000
# 1991      11341240.0      31273853.34  106.315000
# 1992    13241888.845     36670838.585  106.690000
# 1993    13426749.995     40269796.685  107.525000
# 1994     16252273.84     45314628.765  105.570000
# 1995    17724168.785      47241527.42  106.725000
# 1996      20722900.0     49097639.955  107.240000
# 1997      26280725.0     65561378.835  107.260000
# 1998      27311330.0     55880115.795  107.365000
# 1999      33714700.0     67548190.605  109.390000
# 2000      31701250.0     67270649.345  107.850000
# 2001      32231500.0      78088125.74  108.070000
# 2002     31678144.83       85017182.6  105.925000
# 2003      32992150.0      88309660.12  108.925000
# 2004      34986635.0      93608739.06  109.300000
# 2005      35947470.0     89333049.485  108.280000
# 2006      35783500.0     93270351.815  108.660000
# 2007      35327550.0    101918358.995  107.865000
# 2008      37433650.0    108510810.045  106.665000
# 2009      37612500.0    116693403.045  107.115000
# 2010      38263750.0     115532977.67  107.621212
# 2011      39343650.0     124188434.18  107.350000
# 2012      38886475.4    127380950.975  107.673367
# 2013      40508350.0     129979243.37  110.610000
# 2014      37271500.0    132457412.815  110.160000
# 2015     36645630.74     133730055.44  110.535000
# 2016      43932500.0     144694223.96  111.150000
# 2017      37048500.0    142426242.075  111.520000
# 2018      35064900.0    140426447.295  111.500000
# 2019      33292750.0    151698265.205  112.555000
# 2020      34518630.0     113931951.68  109.375000

# %%
# Plot average budget over the years

plt.figure(figsize=(6,4))

time_analysis['budget'].plot(label='Average Budget', color='skyblue', linewidth=2)
plt.title('Average Budget Over Time', fontsize=16)
plt.xlabel('Year',fontsize=14)
plt.ylabel('Average Budget', fontsize=14)
plt.legend()
plt.grid(alpha=0.5)

plt.show()

# %%
# plot average gross over the years
plt.figure(figsize=(6,4))

time_analysis['gross'].plot(color='skyblue', label='Average Gross Revenue')
plt.title('Average Gross Revenue Over Time', fontsize=16)
plt.xlabel('Year', fontsize=14)
plt.ylabel('Average Gross Revenue', fontsize=14)
plt.legend()
plt.grid(alpha=0.5)

plt.show()

# %%
# plot average runtime over the years

plt.figure(figsize=(6,4))

time_analysis['runtime'].plot(label='Average Runtime', color='skyblue')
plt.title('Average Runtime Over Time', fontsize=16)
plt.xlabel('Year', fontsize=14)
plt.ylabel('Average Runtime', fontsize=14)
plt.legend()
plt.grid(alpha=0.5)

plt.show()

# %%
# count the number of movies for each genre per year每年每种电影的数量

genre_trends = df.groupby(['year', 'genre'])['name'].count()
genre_trends
# Out:
# year  genre
# 1980  Action       14
#       Adventure     7
#       Animation     2
#       Biography     6
#       Comedy       36
#                    ..
# 2020  Comedy        3
#       Crime         1
#       Drama         7
#       Horror        2
#       Sci-Fi        1
# Name: name, Length: 415, dtype: int64

# %%
genre_trends = df.groupby(['year', 'genre'])['name'].count().unstack()        
genre_trends
# Out:
# genre  Action  Adventure  Animation  Biography  Comedy  Crime  Drama  Family  \
# year
# 1980     14.0        7.0        2.0        6.0    36.0    4.0   14.0     1.0
# 1981     17.0       11.0        2.0        4.0    29.0    9.0   21.0     NaN
# 1982     21.0        3.0        5.0        5.0    46.0    8.0   21.0     1.0
# 1983     31.0        9.0        2.0        5.0    42.0    9.0   31.0     NaN
# 1984     31.0       13.0        2.0        4.0    63.0    8.0   39.0     NaN
# 1985     42.0       19.0        7.0        9.0    66.0    5.0   39.0     2.0
# 1986     46.0       12.0        6.0        7.0    63.0   13.0   42.0     1.0
# 1987     39.0        7.0        2.0        7.0    73.0   16.0   36.0     NaN
# 1988     31.0       10.0        5.0        8.0    76.0   15.0   39.0     NaN
# 1989     48.0       14.0        4.0       11.0    71.0   12.0   30.0     NaN
# 1990     45.0       10.0        3.0        8.0    66.0   13.0   43.0     NaN
# 1991     41.0        8.0        5.0        6.0    68.0   13.0   51.0     NaN
# 1992     36.0       13.0        5.0       10.0    56.0   25.0   46.0     NaN
# 1993     34.0       11.0        5.0       12.0    61.0   19.0   49.0     1.0
# 1994     38.0       15.0        5.0       13.0    81.0   13.0   29.0     2.0
# 1995     39.0       19.0        6.0        7.0    62.0   19.0   39.0     NaN
# 1996     34.0       12.0        5.0       10.0    80.0   19.0   34.0     NaN
# 1997     51.0        8.0        5.0        9.0    61.0   17.0   41.0     NaN
# 1998     41.0        8.0        8.0        8.0    71.0   19.0   35.0     NaN
# 1999     26.0        8.0        8.0       10.0    72.0   17.0   48.0     NaN
# 2000     35.0       10.0       10.0        9.0    66.0   19.0   44.0     NaN
# 2001     39.0        7.0       13.0        7.0    63.0   15.0   47.0     NaN
# 2002     46.0        9.0        8.0        9.0    53.0   26.0   43.0     NaN
# 2003     50.0       11.0        8.0        9.0    65.0   17.0   30.0     NaN
# 2004     47.0        6.0       11.0       11.0    64.0   13.0   43.0     1.0
# 2005     45.0       16.0        7.0       11.0    62.0   12.0   36.0     NaN
# 2006     43.0       14.0       17.0       17.0    53.0   11.0   33.0     NaN
# 2007     44.0        9.0       11.0       13.0    48.0   27.0   34.0     NaN
# 2008     53.0       12.0       10.0       12.0    51.0   19.0   31.0     NaN
# 2009     44.0       14.0       15.0       13.0    51.0   10.0   39.0     NaN
# 2010     52.0       10.0       10.0       11.0    55.0   13.0   38.0     NaN
# 2011     53.0        9.0       15.0       12.0    45.0    7.0   48.0     NaN
# 2012     47.0       13.0       12.0        8.0    55.0   12.0   40.0     NaN
# 2013     55.0       10.0       12.0       16.0    44.0   15.0   38.0     NaN
# 2014     63.0       10.0       11.0       15.0    44.0    8.0   38.0     NaN
# 2015     56.0        8.0       11.0       22.0    42.0    6.0   45.0     NaN
# 2016     64.0        8.0       19.0       21.0    35.0   10.0   32.0     NaN
# 2017     47.0        9.0       14.0       24.0    33.0   12.0   52.0     1.0
# 2018     53.0       11.0       13.0       33.0    31.0   18.0   30.0     NaN
# 2019     57.0       12.0       17.0       11.0    39.0    7.0   43.0     1.0
# 2020      7.0        2.0        2.0        NaN     3.0    1.0    7.0     NaN
#
# genre  Fantasy  History  Horror  Music  Musical  Mystery  Romance  Sci-Fi  \
# year
# 1980       1.0      NaN     6.0    NaN      NaN      NaN      NaN     1.0
# 1981       NaN      NaN    17.0    1.0      NaN      NaN      1.0     NaN
# 1982       1.0      NaN    11.0    NaN      NaN      NaN      NaN     2.0
# 1983       1.0      1.0    10.0    NaN      NaN      NaN      NaN     1.0
# 1984       NaN      NaN     7.0    NaN      NaN      NaN      1.0     NaN
# 1985       2.0      NaN     6.0    NaN      NaN      NaN      NaN     NaN
# 1986       NaN      NaN     8.0    NaN      NaN      NaN      NaN     1.0
# 1987       4.0      NaN    14.0    NaN      NaN      NaN      NaN     NaN
# 1988       4.0      NaN     9.0    NaN      NaN      1.0      1.0     NaN
# 1989       3.0      NaN     7.0    NaN      NaN      NaN      NaN     NaN
# 1990       1.0      NaN     8.0    NaN      NaN      1.0      NaN     1.0
# 1991       1.0      NaN     4.0    NaN      NaN      3.0      NaN     NaN
# 1992       2.0      NaN     5.0    NaN      NaN      1.0      1.0     NaN
# 1993       2.0      NaN     5.0    NaN      NaN      NaN      NaN     NaN
# 1994       1.0      NaN     2.0    NaN      NaN      1.0      NaN     NaN
# 1995       2.0      NaN     6.0    NaN      NaN      1.0      NaN     NaN
# 1996       1.0      NaN     4.0    NaN      NaN      1.0      NaN     NaN
# 1997       2.0      NaN     5.0    NaN      NaN      1.0      NaN     NaN
# 1998       1.0      NaN     8.0    NaN      NaN      NaN      1.0     NaN
# 1999       2.0      NaN     6.0    NaN      NaN      2.0      1.0     NaN
# 2000       NaN      NaN     4.0    NaN      NaN      1.0      2.0     NaN
# 2001       2.0      NaN     7.0    NaN      NaN      NaN      NaN     NaN
# 2002       NaN      NaN     6.0    NaN      NaN      NaN      NaN     NaN
# 2003       1.0      NaN     7.0    NaN      NaN      2.0      NaN     NaN
# 2004       NaN      NaN     4.0    NaN      NaN      NaN      NaN     NaN
# 2005       NaN      NaN    10.0    NaN      NaN      NaN      NaN     NaN
# 2006       1.0      NaN    10.0    NaN      NaN      1.0      NaN     NaN
# 2007       2.0      NaN    10.0    NaN      NaN      NaN      NaN     2.0
# 2008       1.0      NaN     9.0    NaN      NaN      NaN      1.0     NaN
# 2009       NaN      NaN    14.0    NaN      NaN      NaN      NaN     NaN
# 2010       1.0      NaN     9.0    NaN      NaN      1.0      NaN     NaN
# 2011       1.0      NaN     7.0    NaN      NaN      1.0      1.0     1.0
# 2012       NaN      NaN    12.0    NaN      NaN      1.0      NaN     NaN
# 2013       1.0      NaN     9.0    NaN      NaN      NaN      NaN     NaN
# 2014       NaN      NaN     9.0    NaN      NaN      1.0      NaN     NaN
# 2015       NaN      NaN     9.0    NaN      NaN      NaN      NaN     NaN
# 2016       NaN      NaN    11.0    NaN      NaN      NaN      NaN     NaN
# 2017       NaN      NaN     8.0    NaN      NaN      NaN      NaN     NaN
# 2018       1.0      NaN    10.0    NaN      NaN      NaN      NaN     NaN
# 2019       2.0      NaN     7.0    NaN      2.0      NaN      NaN     NaN
# 2020       NaN      NaN     2.0    NaN      NaN      NaN      NaN     1.0
#
# genre  Sport  Thriller  Western
# year
# 1980     NaN       NaN      NaN
# 1981     NaN       NaN      1.0
# 1982     NaN       1.0      1.0
# 1983     NaN       2.0      NaN
# 1984     NaN       NaN      NaN
# 1985     NaN       3.0      NaN
# 1986     NaN       1.0      NaN
# 1987     NaN       2.0      NaN
# 1988     NaN       1.0      NaN
# 1989     NaN       NaN      NaN
# 1990     NaN       1.0      NaN
# 1991     NaN       NaN      NaN
# 1992     NaN       NaN      NaN
# 1993     NaN       NaN      1.0
# 1994     NaN       NaN      NaN
# 1995     NaN       NaN      NaN
# 1996     NaN       NaN      NaN
# 1997     NaN       NaN      NaN
# 1998     NaN       NaN      NaN
# 1999     NaN       NaN      NaN
# 2000     NaN       NaN      NaN
# 2001     NaN       NaN      NaN
# 2002     NaN       NaN      NaN
# 2003     NaN       NaN      NaN
# 2004     NaN       NaN      NaN
# 2005     NaN       1.0      NaN
# 2006     NaN       NaN      NaN
# 2007     NaN       NaN      NaN
# 2008     NaN       1.0      NaN
# 2009     NaN       NaN      NaN
# 2010     NaN       NaN      NaN
# 2011     NaN       NaN      NaN
# 2012     NaN       NaN      NaN
# 2013     NaN       NaN      NaN
# 2014     NaN       1.0      NaN
# 2015     NaN       1.0      NaN
# 2016     NaN       NaN      NaN
# 2017     NaN       NaN      NaN
# 2018     NaN       NaN      NaN
# 2019     1.0       1.0      NaN
# 2020     NaN       NaN      NaN

# %%
# plot genre trends over the years

genre_trends.plot(kind='line', figsize=(12,8), linewidth=2)

plt.title('Trends of Movie Genres Over Time', fontsize=16)
plt.xlabel('Year', fontsize=14)
plt.ylabel('Number of movies', fontsize=14)
plt.legend(title='Genre', bbox_to_anchor=(1.05, 1), loc='upper left')
plt.grid(alpha=0.5)

plt.show()

# %%
# Count movies by country
movies_by_country = df['country'].value_counts().head(10)
movies_by_country
# Out:
# United States     5475
# United Kingdom     816
# France             279
# Canada             190
# Germany            117
# Australia           92
# Japan               81
# India               62
# Italy               61
# Spain               47
# Name: country, dtype: int64

# %%
# plot top 10 movie-producing countries
plt.figure(figsize=(6,6))

movies_by_country.plot(kind='bar', color='pink')

plt.title('Top 10 movie-producing counties', fontsize=16)
plt.xlabel('Country', fontsize=14)
plt.ylabel('Number of movies', fontsize=14)
plt.xticks(rotation=45, ha='right')
plt.tight_layout()

plt.show()

# %%
# Group by country and calculate average gross and score
country_analysis = df.groupby('country')[['gross', 'score']].mean().sort_values(by='gross', ascending=False).head(10)
country_analysis
# Out:
#                                  gross     score
# country
# Malta                      352794081.0  6.500000
# New Zealand               254189277.84  7.420000
# China                    219735745.025  6.702500
# Finland               169193791.333333  6.033333
# United Arab Emirates        88586133.0  6.000000
# United States          88302970.389041  6.257072
# South Africa                70898487.0  6.487500
# Lebanon                     64417003.0  8.400000
# United Kingdom         59987987.042892  6.642770
# Germany                53150348.606838  6.436752

# %%
# plot top 10 countries by average gross revenue
plt.figure(figsize=(6,6))

country_analysis['gross'].plot(kind='bar', color='skyblue')

plt.title('Top 10 Countries by Average Gross Revenue', fontsize=16)
plt.xlabel('Country', fontsize=14)
plt.ylabel('Average Gross Revenue', fontsize=14)
plt.xticks(rotation=45, ha='right')
plt.tight_layout()

plt.show()

# %%
# plot top 10 Countries by average IMDb score
plt.figure(figsize=(6,5))

country_analysis['score'].plot(kind='bar', color='pink')

plt.title('Top 10 Countries by Average IMDb Score', fontsize=16)
plt.xlabel('Country', fontsize=14)
plt.ylabel('Average IMDb Score', fontsize=14)
plt.xticks(rotation=45, ha='right')
plt.tight_layout()

plt.show()

# %%
# Count the occurrences of each genre
genre_counts = df['genre'].value_counts()
genre_counts
# Out:
# Comedy       2245
# Action       1705
# Drama        1518
# Crime         551
# Biography     443
# Adventure     427
# Animation     338
# Horror        322
# Fantasy        44
# Mystery        20
# Thriller       16
# Family         11
# Sci-Fi         10
# Romance        10
# Western         3
# Musical         2
# Sport           1
# Music           1
# History         1
# Name: genre, dtype: int64

# %%
# plot the most common genres
plt.figure(figsize=(6,4))

sns.barplot(x=genre_counts.values, y=genre_counts.index, palette='viridis')

plt.title('Most Common Movies Genres', fontsize=16)
plt.xlabel('Number of Movies', fontsize=14)
plt.ylabel('Genre', fontsize=14)
plt.grid(alpha=0.4)

plt.show()

# %%
# find the highest-grossing movies per year
highest_grossing_years = df.groupby(['year'])['gross'].max()
highest_grossing_years
# Out:
# year
# 1980     538375067
# 1981     389925971
# 1982     792910554
# 1983     475106177
# 1984     333107271
# 1985     381906762
# 1986     357288178
# 1987     320145693
# 1988     354825435
# 1989     474171806
# 1990     505703557
# 1991     520881154
# 1992     504050219
# 1993    1033928303
# 1994    1083720877
# 1995     394436586
# 1996     817400891
# 1997    2201647264
# 1998     553709788
# 1999    1027082707
# 2000     546388108
# 2001    1006968171
# 2002     947495095
# 2003    1146030912
# 2004     928760770
# 2005     896678241
# 2006    1066179747
# 2007     960996492
# 2008    1005973645
# 2009    2847246203
# 2010    1066970811
# 2011    1342321665
# 2012    1518815515
# 2013    1281508100
# 2014    1104054072
# 2015    2069521700
# 2016    1153337496
# 2017    1332698830
# 2018    2048359754
# 2019    2797501328
# 2020     461421559
# Name: gross, dtype: Int64

# %%
df['gross'].max()
# Out:
# 2847246203

# %%
avg_score_by_star = df.groupby('star')['score'].mean().sort_values(ascending=False).head(10)
avg_score_by_star
# Out:
# star
# Alexandre Rodrigues    8.6
# Philippe Noiret        8.5
# Mark Hamill            8.5
# Kay Kay Menon          8.5
# Luigi Lo Cascio        8.5
# Ben Burtt              8.4
# Ulrich Mühe            8.4
# Anthony Gonzalez       8.4
# Zain Al Rafeea         8.4
# Choi Min-sik           8.4
# Name: score, dtype: float64

# %%
# find out the movie with the highest gross revenue each year

max_gross_idx = df.groupby('year')['gross'].idxmax()

top_gross_movies_per_year = df.loc[max_gross_idx, ['year', 'name', 'gross']].sort_values('year')

top_gross_movies_per_year = top_gross_movies_per_year.reset_index(drop=True)

top_gross_movies_per_year
# Out:
#     year                                            name       gross
# 0   1980  Star Wars: Episode V - The Empire Strikes Back   538375067
# 1   1981   Indiana Jones and the Raiders of the Lost Ark   389925971
# 2   1982                      E.T. the Extra-Terrestrial   792910554
# 3   1983      Star Wars: Episode VI - Return of the Jedi   475106177
# 4   1984            Indiana Jones and the Temple of Doom   333107271
# 5   1985                              Back to the Future   381906762
# 6   1986                                         Top Gun   357288178
# 7   1987                                Fatal Attraction   320145693
# 8   1988                                        Rain Man   354825435
# 9   1989              Indiana Jones and the Last Crusade   474171806
# 10  1990                                           Ghost   505703557
# 11  1991                      Terminator 2: Judgment Day   520881154
# 12  1992                                         Aladdin   504050219
# 13  1993                                   Jurassic Park  1033928303
# 14  1994                                   The Lion King  1083720877
# 15  1995                                       Toy Story   394436586
# 16  1996                                Independence Day   817400891
# 17  1997                                         Titanic  2201647264
# 18  1998                                      Armageddon   553709788
# 19  1999       Star Wars: Episode I - The Phantom Menace  1027082707
# 20  2000                          Mission: Impossible II   546388108
# 21  2001           Harry Potter and the Sorcerer's Stone  1006968171
# 22  2002           The Lord of the Rings: The Two Towers   947495095
# 23  2003   The Lord of the Rings: The Return of the King  1146030912
# 24  2004                                         Shrek 2   928760770
# 25  2005             Harry Potter and the Goblet of Fire   896678241
# 26  2006      Pirates of the Caribbean: Dead Man's Chest  1066179747
# 27  2007        Pirates of the Caribbean: at World's End   960996492
# 28  2008                                 The Dark Knight  1005973645
# 29  2009                                          Avatar  2847246203
# 30  2010                                     Toy Story 3  1066970811
# 31  2011    Harry Potter and the Deathly Hallows: Part 2  1342321665
# 32  2012                                    The Avengers  1518815515
# 33  2013                                          Frozen  1281508100
# 34  2014                 Transformers: Age of Extinction  1104054072
# 35  2015      Star Wars: Episode VII - The Force Awakens  2069521700
# 36  2016                      Captain America: Civil War  1153337496
# 37  2017         Star Wars: Episode VIII - The Last Jedi  1332698830
# 38  2018                          Avengers: Infinity War  2048359754
# 39  2019                               Avengers: Endgame  2797501328
# 40  2020                               The Eight Hundred   461421559
